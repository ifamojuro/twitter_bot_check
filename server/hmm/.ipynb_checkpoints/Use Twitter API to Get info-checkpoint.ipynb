# %%
import tweepy

# %%
#keys
consumer_key = '6qhxfyGHdnt92g25yi0W48NRY'
consumer_secret = 'UlkNAzJx1dMqOBShRRyQsGqRB5hKvzkhL0VfiMb3vN7KK7mEij'
access_token = '2713535500-1X6ji2Z0KnSQWKz4fLFYX0XDtfQ1BjKt2XVfaTc'
access_token_secret = 'PFU0cESnQp7J7QHiZy0tdXrvdR91dtmm6g9vGKQwK33nj'

# %%
auth = tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth)

# %%
auth.set_access_token(access_token, access_token_secret)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-989d9811ce22> in <module>()
# ----> 1 auth.set_access_token(access_token, access_token_secret)
#
# AttributeError: 'AppAuthHandler' object has no attribute 'set_access_token'

# %%
ids = []
for page in tweepy.Cursor(api.friends_ids, screen_name="KingLoye").pages():
    ids.extend(page)

# %%
screen_names = []

# %%
for i in range(0, len(ids), 100):
    seg = ids[i: i+100]
    #relevant info is screen name, friends_count, num_tweets
    users = [user.screen_name for user in api.lookup_users(user_ids=seg)]
    screen_names.extend(users)

# %%
screen_names
# Out:
# ['rabois',
#  '_DanielSinclair',
#  'OkiLegend',
#  'MakingCentsPC',
#  'Nia__imani',
#  'brainpicker',
#  '___bambii_',
#  'Slum2School',
#  'itsnemie',
#  'wildhormoans',
#  'temite',
#  'glory_osei',
#  'CJFDillow',
#  'busanga',
#  'Jaaytunechi',
#  'NigeriaNumeric',
#  'LALAALAKIJA',
#  '_KBoateng',
#  'Bertdora',
#  'Its_Deji',
#  'toluL_',
#  'dkskinjermaine',
#  'SophieChandauka',
#  'pmarca',
#  'moni_owoade',
#  'BaldingsWorld',
#  'minkyxo',
#  'typesfast',
#  'AfCfta',
#  'jacquieotag',
#  'AubreyHruby',
#  'NnekaJennifer',
#  'atrium',
#  'KuperSimon',
#  'siobhan_ogrady',
#  'waitwait',
#  'A_zayyy',
#  'osaeB',
#  'laphamsquart',
#  'Wimbart',
#  'ChakaStocks',
#  'maxImeaner',
#  'EmmanuelFreuden',
#  'ShoutsAndMiras',
#  'kopalo',
#  'ChibunduOnuzo',
#  'PeejOPJ',
#  'TokunboAkerele',
#  'Camusredux',
#  'paulg',
#  'Ifawemimo',
#  'fahims',
#  'Ibrahimaa_',
#  'cyberomin',
#  'LagosUrbanDevIn',
#  'BintzRealist',
#  'DamiAdewuyi',
#  'overlyxclusive',
#  'royafrisoc',
#  'africaarguments',
#  'prepaid_africa',
#  'daily_trust',
#  'ProfFeynman',
#  'P0dSaveAfrica',
#  'MartinEigbike',
#  'ameerabourgi',
#  'qikipedia',
#  'TheAncientSage',
#  'techreview',
#  'Morountodun_',
#  'Iredeadunni',
#  'aChildOf2Worlds',
#  'folabilaw',
#  'cruelsantino',
#  'docolumide',
#  'AVCA_Africa',
#  'MoMoneyyyyy__',
#  'HausmanLLC',
#  'DolapoOmidire',
#  'DamiAdepoju',
#  'PedrosAfrica',
#  'peculiarjimjam',
#  'senisulyman',
#  'MaryamDWHxo',
#  'mims',
#  'DelsAkin',
#  'shl',
#  'OlumbeAKinkugbe',
#  'EbukaNweke_',
#  'shezinxir',
#  'Tobs_OF',
#  'LagosCapitalist',
#  'addozie',
#  'alkayy',
#  'Mochievous',
#  'RayDalio',
#  'CrazyPolymath',
#  'tayooye',
#  'bukssssss',
#  'DamiAdy',
#  'mbmalabu',
#  'O_rae',
#  'adeyeni__',
#  'kemiadeyemii',
#  'nevinomics',
#  'JeremyTabansi',
#  'OyihomaX',
#  'MobayoO',
#  'TNussinov',
#  'theycallmeTUNE',
#  'stepmoyo',
#  'fayoscosco',
#  'dbrownAnalyst',
#  'manlikedami',
#  'ade_olopade',
#  'tomie_a',
#  'LifeMathMoney',
#  'ProjectWigan',
#  'TheNewPractice',
#  'tweetsbymo',
#  'ndidiNwuneli',
#  'AmakaAnku',
#  'ChisAdventures',
#  'sbmintelligence',
#  '_Simisola_O',
#  'Pr1y3',
#  'ife__michelle',
#  'Tuedss',
#  'sade_ona',
#  'registability',
#  'Afrocheri',
#  'RyanHoliday',
#  'OgbeniDipo',
#  'BukayoA',
#  'madayo',
#  '_Affi_A',
#  'Punthief',
#  'MODiyaolu',
#  'tunde_oo',
#  'kingpam___',
#  'TFL__tfl',
#  'koyegbeke',
#  'NosaAguebor',
#  'ChroniclesofLA',
#  'saaam_am',
#  'molarawood',
#  'the868',
#  'Ekanem__',
#  'delectableseun',
#  'tobi_lawson',
#  'JimiDemi',
#  '_RMOx',
#  'Koffss_',
#  'Jaiyee',
#  'WeMoveCo',
#  'scalemyhustle',
#  'traveldenng',
#  'YosolaO',
#  'TaibatLawanson',
#  'Realtor_NG',
#  'MalaikaToyo',
#  'gimbakakanda',
#  'justinkan',
#  'FacilitateFx',
#  'OsinubiHimself',
#  'MRERo',
#  'lexiibam',
#  'anu_adesanya',
#  'tosinolaseinde',
#  'muftimenk',
#  'RumexxCapital',
#  'ChifeDr',
#  'SecretFlying',
#  'EkaetteAfia',
#  'OdunoluwaL',
#  'HowIBuiltThis',
#  'OneMadTitan',
#  'onlyAyos',
#  'Gozie_O_',
#  'manifestive',
#  'fikss96',
#  'Pensage',
#  'faregbaj',
#  'maxsiollun',
#  'Vic_C_E',
#  'neiLmunshi',
#  'muyiwag',
#  'DaytonaDreamin_',
#  'DerinAdebayo',
#  'Chinyeree__',
#  'Ibilola_',
#  'PurpletweetyB',
#  'IamAkinnola_O',
#  'SimuChigudu',
#  'Jite_',
#  'yungnollywood',
#  '_Ayooluwa',
#  'AishaSalaudeen',
#  'bhary0ur',
#  'Chin_iAm',
#  'kunmicoker',
#  'mmay3r',
#  'YeleBademosi',
#  'EditiEffiong',
#  'TheStoicEmperor',
#  'ChijiokeD',
#  'kola_aina',
#  'TravelVida',
#  'Folakunmi_A',
#  'mau_dej',
#  'demiakingbe',
#  'SHEISUKI',
#  'philhazlewood',
#  'Ajoke_George',
#  'Noahpinion',
#  'OnePerfectShot',
#  '90sSugarDaddy',
#  'Maffffssss',
#  'Yorubafacts',
#  'Theycallmetobi',
#  'victorsozaboy',
#  'asteroid_saku',
#  'kolatubosun',
#  'Ayishat_Akanbi',
#  'AbangMercy',
#  'andrewfootie',
#  'bosuntijani',
#  'simonkolawole',
#  'Abiolajazz',
#  'Vans_Obi',
#  'Tito_Jay',
#  'archpng',
#  'SaeeduH',
#  'djRudii_',
#  'SeunA_',
#  'hallaboutafrica',
#  'SimShagaya',
#  'GregNoire',
#  'LiamPaulCanning',
#  'DollsBamgboye',
#  'davidpilling',
#  'seunsmith',
#  'TojuAdedeji',
#  'ShecrownLita',
#  'BABAmiLEKO',
#  'JoshuaKissi',
#  'nnayo_o',
#  'abxola',
#  'ayodejirotinwa',
#  'MohiniUfeli',
#  'naval',
#  'xniyi',
#  'EromoEgbejule',
#  'WCS_Nigeria',
#  'bilikiss',
#  'NNPtweets',
#  'Mikey_Fam',
#  'mungerisms',
#  'yoruba_proverbs',
#  'TundeIrukera',
#  'jasonzweigwsj',
#  'GbenroAdegbola',
#  'ReformedBroker',
#  'CNNAfrica',
#  'misanrewane',
#  'NOA_Nigeria',
#  'rachelmsavage',
#  'OmotolaAriyo_',
#  'knightofdelta',
#  'Kay_O_Kalu',
#  'jibola_oki',
#  'nayyirahwaheed',
#  'its_tofa',
#  'TefoMohapi',
#  'Alloraa_',
#  'TosinAshafa',
#  'GeraldSagoe',
#  'asymco',
#  'PeterOzzy',
#  'JamesClear',
#  'waleajibade',
#  'artofwar_suntzu',
#  'PaulWallace123',
#  'TradeInvestNG',
#  'SoledadFrancis',
#  'YinkaWrites',
#  'TheYomiKazeem',
#  'kaushikcbasu',
#  'purefoyAMEBO',
#  'gucci1017',
#  'dozieokk',
#  'Nun_River',
#  'blossomozurumba',
#  'SoleilLevantK',
#  'eldivyn',
#  'RumuWonodi',
#  'TimeyinPI',
#  'DrDotun',
#  'andyRoidO',
#  'Femi_fabio',
#  'afdozie',
#  'LopesInsights',
#  'Dolllss',
#  'ArtificialLawya',
#  'EfosaOjomo',
#  'kelechi_naba',
#  'YiddishProverbs',
#  'vivalabada',
#  'BBCAfrica',
#  'TheFifographer',
#  'Randomexe',
#  'dimejisofowora',
#  'FadekemiAbiru',
#  'ImohUmoren',
#  'YrsaDaleyWard',
#  'akediia',
#  'farnamstreet',
#  'ovxosu',
#  'qzafrica',
#  'Ruud_bishop',
#  'bisiogunwale',
#  'AffiSupaStar',
#  'hartng',
#  'officialkuddi',
#  'republicjournal',
#  'ijeomaumebinyuo',
#  'orwellguy',
#  'LarryUchN',
#  'OpeRunzy',
#  'emose__',
#  'AbiiSola',
#  'BabaMJ',
#  'wolfofnewstreet',
#  'niyiokeowo',
#  'LadyDonli',
#  '_DDesigns_',
#  'MatthewTPage',
#  'allafrica',
#  'SeeMeSeeNigeria',
#  'Wami_Aluko',
#  'CallMeBenfigo',
#  'Timi_OD',
#  'MagnumPhotos',
#  'enyeasi',
#  'BabaAgba_',
#  'StearsBusiness',
#  'iconicDemoe',
#  'FUGAThePirate',
#  'NativeMag',
#  'iTweetBanter',
#  'LoLalade',
#  'odunsitheengine',
#  'TSE____',
#  'Gbengaolaniyii',
#  'IrenosenOkojie',
#  'TheTobiSmith',
#  'theirinjournal',
#  'PosiOg',
#  'Daytea_O',
#  '_Logor',
#  'Ebss_A',
#  'feyikewa',
#  '_HONESTMOMENTS_',
#  'LaVidaLolaaa',
#  'JudeJagger',
#  'AkinSawyerr',
#  'adage',
#  'nonso2',
#  'OnlyAfricaFacts',
#  'fathermerry',
#  'stephhegarty',
#  'Mimalee_',
#  'blackthought',
#  '_teetaiwo',
#  'trustfundbaby',
#  'daymee98',
#  'mannyjefferson',
#  'joshuaoj',
#  'MissDambo',
#  'Asiyaa_A',
#  'ikeanya',
#  'George_tade',
#  'steffi_teresa',
#  'thatguyKev',
#  'T_Osho',
#  'bolu_ay',
#  'JoshTabansi',
#  'kayodea',
#  'TheHeadphones91',
#  'Muazzam_Dgn',
#  'TheBlackHermit',
#  'SeyiAlake',
#  'aasiyahjasmine',
#  'SonariwoOnDeck',
#  'Rumi_Quote',
#  'nowahalastories',
#  'Titilola__',
#  'AdviceToWriters',
#  'ansatsu_sha',
#  'Griffinreborn',
#  'hofrench',
#  'AndersonPaak',
#  'MayowaIdowu',
#  'iKillCuriosity',
#  'Jollz',
#  'folapinheiro',
#  'EghosaO',
#  'Kingwole',
#  'Temisque',
#  'ChineEzeks',
#  'timigod',
#  'OdunEweniyi',
#  'officiallyk10',
#  'AfroVII',
#  'elnathan_john',
#  'almitaa_bonitaa',
#  'siddhmi',
#  'RobertGreene',
#  'dailystoic',
#  'NewsomCA',
#  'TrackaNG',
#  'MrExposed',
#  'Serafina_Atta',
#  '9jafoodie',
#  'wonu2sides',
#  'ayosogunro',
#  'tundeleye',
#  'Ephraimm_',
#  'Damocleansword',
#  'mickjenkins',
#  'Kitchnbutterfly',
#  'eyooekpo',
#  'adaobi_oe',
#  'adri1jnr',
#  'ImadMesdoua',
#  'bryantlikekobe_',
#  'Actionpoulet',
#  'gidimeister',
#  'nicholasibekwe',
#  'manmustwack',
#  'Audu',
#  'JavierBlas',
#  'iamforbes',
#  'Ms_Zelaa',
#  'gsopitan',
#  'AO1379',
#  'Official_Ayraf',
#  'VenturesAfrica',
#  'business',
#  'archittiwari',
#  'Echecrates',
#  'qaywee',
#  '0x',
#  'Seunoduyale',
#  'TravelNoire',
#  'gbenga_III',
#  'MetroBoomin',
#  'aadetugbo',
#  'kenyanpundit',
#  'jeremyweate',
#  'Bashorun_Adio',
#  'aminugamawa',
#  'BBoason',
#  'TunjiAndrews',
#  'stanleyazuakola',
#  'StanVito',
#  'JibrinIbrahim17',
#  'TexTheLaw',
#  'seyitaylor',
#  'elonmusk',
#  'cchukudebelu',
#  'tundefashola',
#  'SeyiAree',
#  'vtsereteli1',
#  'FailedRift',
#  'BudgITng',
#  'seunonigbinde',
#  '_Nosa_',
#  'OoTheNigerian',
#  'toluogunlesi',
#  'ugodre',
#  'Dolarpo',
#  'dejiawoniyi',
#  'MaggieFick',
#  'CWallop',
#  '_Kaelo_',
#  'ChubaEzeks',
#  'asemota',
#  'iaboyeji',
#  'obyezeks',
#  'JohnBrewin_',
#  'ManUtdInPidgin',
#  'EatDrinkLagos',
#  'akin_adesina',
#  'WalleLawal',
#  'afropolitanvibe',
#  'NaijaFlyingDr',
#  'Fieldinsight_co',
#  'BBGAfrica',
#  'bhorowitz',
#  'afalli',
#  'marko_protic',
#  'DoubleEph',
#  'mrO4real',
#  'tvpfumaneyi_',
#  'thekidsamazing',
#  'Uduak_Ekanem',
#  'HibsAhmed',
#  'officialtemibtm',
#  'ChiliPeppers',
#  '_Abimbolaoshodi',
#  'MrBankole',
#  'MisterCompton92',
#  'jvardon',
#  'WSHHFANS',
#  'MAJORLAZER',
#  'diplo',
#  'hiunka',
#  'CallMe_Bohnnie',
#  'El_Don_Chichi',
#  'TheEconomist',
#  'maggierambles',
#  'bini_magic',
#  'feanyicy',
#  'ljbans',
#  'TofunwaA',
#  'LanreOyedotun',
#  'MelvinTaylorII',
#  'jwg15_',
#  'ItsHimTega',
#  'dvmilola',
#  'ManUtd',
#  'Gjaimes007',
#  'rasav21',
#  'callmelizmael',
#  'javierayala10']

# %%
screen_names
# Out:
# ['JohnLegere',
#  'chartdata',
#  'alex_youre',
#  'ataaaaa_a',
#  'OBTJOBS',
#  'priyapus',
#  'joinpursuit',
#  'NYCCOIB',
#  'xclaguarda',
#  'isadoorabel',
#  'ari_ophelia',
#  'sportswithjohn',
#  'volunTEENnation',
#  'Neilicorn',
#  'buttonpoetry',
#  'Fyffes_Na',
#  'DRichards13',
#  'Deji',
#  '1SGODBODY',
#  'Behzinga',
#  'wroetoshaw',
#  'miniminter',
#  'MatthewEspinosa',
#  'UrbanFortuneCO',
#  'DanCrea_',
#  'Vikkstar123',
#  'ZerkaaHD',
#  'KSIOlajidebt',
#  'camphalfblood',
#  'daniellempaige',
#  'Tobjizzle',
#  'JaredOfNY',
#  'I_Am_Hannibal_L',
#  'tomck1234',
#  'TweetsByPink',
#  'donaldglover',
#  'ahsanissa69',
#  'NYCunity',
#  'Connectionsny1',
#  'KingLoye',
#  'theprospectblog',
#  'Rockawaytimes',
#  'KhaleelAnderson',
#  'PesachOsina',
#  'MilanRTaylor',
#  'RockawayYouth']

# %%
for name in screen
# Out:
#   File "<ipython-input-1-90a016c294b3>", line 1
#     for name in screen
#                       ^
# SyntaxError: invalid syntax
